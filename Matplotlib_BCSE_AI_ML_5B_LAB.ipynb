# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,2.4,3,4,2.6]

plt.title("Graph Draw")
plt.xlabel("my x-axis")
plt.ylabel("y-axis")

plt.plot(x,y)
plt.figure(figsize=(150,200))
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[1,2,3,4]

plt.title("Graph plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.bar(x,y)
plt.figure(figsize=(150,200))
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[1,2,3,4]

plt.title("Graph plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.scatter(x,y)
plt.figure(figsize=(150,200))
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[0.8,2.5,3.3,4]

plt.title("Graph plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.hist(y)
plt.figure(figsize=(150,200))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[1,2,3,4]
y=[1,2,3,4]

plt.title("Graph plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.grid()
#plt.figure(figsize=(150,200))
plt.show()
